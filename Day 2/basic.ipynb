# %%
num=int(input("Enter number"))

print("The number*10 is ",num*10)
# Out:
# The number*10 is  500

# %%
a=5
b=3
print("value of a is",a,"and value of b is",b)
# Out:
# value of a is 5 and value of b is 3

# %% [markdown]
# # f-string

# %%
a=5
b=3
print(f"value of a is {a} and value of b is {b}")
# Out:
# value of a is 5 and value of b is 3

# %%
model_name="Descision Tree"
accuracy=1.2365
print(f"Accuracy for {model_name} is {accuracy:.3%}")
print(f"Accuracy for {model_name} is {accuracy:.3f}")
print(f"Accuracy for {model_name} is {accuracy:.3}")
# Out:
# Accuracy for Descision Tree is 123.650%
# Accuracy for Descision Tree is 1.236
# Accuracy for Descision Tree is 1.24

# %% [markdown]
# # Comparison Operators

# %%
x = 15
y = 4
print(x==y)
print(x!=y)
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # Logical Operators

# %%
x = 15
y = 4
print(x>10 and y<5)
# Out:
# True

# %%
x = 15
y = 4
print(x>10 or y>5)
# Out:
# True

# %%
b=10
print(b)
print(not b)
# Out:
# 10
# False

# %% [markdown]
# # Conditional Statement

# %%
a = 5
b = 10

if b > a:
    print("b is greater than a")
print("This is the normal program")
# Out:
# b is greater than a
# This is the normal program

# %%
a = 5
b = 10

if b > a:
    print("b is greater than a")
else:
    print("a is greater than b")
# Out:
# b is greater than a

# %% [markdown]
# # Data Structure

# %%
List=[10,5,8,6]
Tuple=(10,5,8,6)
Set={10,5,8,6}

print(List,type(List))
print(Tuple,type(Tuple))
print(Set,type(Set))
# Out:
# [10, 5, 8, 6] <class 'list'>
# (10, 5, 8, 6) <class 'tuple'>
# {8, 10, 5, 6} <class 'set'>

# %%
print(List[2])
print(Tuple[1])
# print(Set[1])   set is unordered and does not support indexing
# Out:
# 8
# 5

# %%
List[2]=20
print(List)
# Out:
# [10, 5, 20, 6]

# %%
List.append(50)
print(List)
# Out:
# [8, 30, 50]

# %%
List.insert(2,30)
print(List)
# Out:
# [8, 30]

# %%
List.remove(5)
print(List)
# Out:
# [10, 8, 6]

# %%
List.pop(0)
print(List)
# Out:
# [8]

# %%
tuple1=(1,2,10,4,5,6)
# tuple.append(20)
# print(tuple)

# %%
sample=list(tuple1)
sample.append(20)
print(sample)
# Out:
# [1, 2, 10, 4, 5, 6, 20]

# %%
example=[10,2,2,3,5,6,6]
print(set(example))
# Out:
# {2, 3, 5, 6, 10}

# %%
example_tuple=(10,2,2,3,5,6,6)
print(set(example_tuple))
# Out:
# {2, 3, 5, 6, 10}

# %%
set_A={10,12,5,3,8}
set_B={8,15,20,10}
list_C=[10,12,5,3,8]
tuple_D=(8,15,20,10)

common_set=set_A.intersection(set_B)
print(common_set)
# Out:
# {8, 10}

# %%
print(set_A & set_B)
# Out:
# {8, 10}

# %%
print(list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(list_C & set_A)
#
# TypeError: unsupported operand type(s) for &: 'list' and 'set'

# %%
print(set_A.union(set_B))
# Out:
# {3, 5, 8, 10, 12, 15, 20}

# %%
train_labels=['cat','dog','bird','cat','dog']
test_labels=['dog','fish','cat','fish','rabbit']


train_labels_set=set(train_labels)
test_labels_set=set(test_labels)

# print(train_labels_set)
# print(test_labels_set)

common_set_2=test_labels_set.difference(train_labels_set)
print(common_set_2)

common_set_3=test_labels_set.union(train_labels_set)
print(common_set_3)

print(len(test_labels)>=len(test_labels_set))
# Out:
# {'fish', 'rabbit'}
# {'fish', 'dog', 'rabbit', 'bird', 'cat'}
# True
