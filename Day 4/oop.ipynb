# %% [markdown]
# # OOP

# %%
class House:
    has_a_roof = True

    def repaint(self):
        print("House needs repainting")


house_1 = House()
house_2 = House()
print(house_1.has_a_roof)
print(house_2.has_a_roof)

house_1.repaint()
# Out:
# True
# True
# House needs repainting

# %%
# Question
# import math


# class Circle:

#     def calculate_area(self, radius):
#         return math.pi * radius**2


# circle_1 = Circle()
# print(circle_1.calculate_area(49))
# Out:
# 7542.9639612690935

# %%
import math


class Circle:

    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius**2


circle_1 = Circle(7)
print(circle_1.calculate_area())
# Out:
# 153.93804002589985
