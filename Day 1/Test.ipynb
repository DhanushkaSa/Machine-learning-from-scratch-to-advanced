# %%
print("Hello World")

# %% [markdown]
# # This is Markdown

# %%
x=10
print(x)
# Out:
# 10

# %%
# Weak names
x=0.91
data=[1,0,1,1]

#Better names
validation_accuracy=0.91
training_labels=[1,0,1,1]

print(validation_accuracy)
print(training_labels)
# Out:
# 0.91
# [1, 0, 1, 1]

# %%
print(type(validation_accuracy))
# Out:
# <class 'float'>

# %%
abc=None
print(type(abc))
# Out:
# <class 'NoneType'>

# %%
sample_id='IMG_001'
label='cat'
width=224
confidence=0.9725
is_correct=True
notes=None

print(type(sample_id))
print(type(label))
print(type(width))
print(type(confidence))
print(type(is_correct))
print(type(notes))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
file_name='test data'
print(file_name.upper())

file='TEST DATA'
print(file_name.lower())
# Out:
# TEST DATA
# test data

# %%
print(len(file_name))
# Out:
# 9

# %%
file_name="            review_001.txt         "
print(file_name)
print(file_name.strip())
# Out:
#             review_001.txt
# review_001.txt

# %% [markdown]
# # Complex data type

# %%
z=2+3j
print(z)
print(type(z))
# Out:
# (2+3j)
# <class 'complex'>

# %%
x=0.1+0.2
print(x)
# Out:
# 0.30000000000000004

# %%
num_1=4.65e7
print(num_1)
print(type(num_1))
# Out:
# 46500000.0
# <class 'float'>
