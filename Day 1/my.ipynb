# %%
course_name='CAME'
week=1
print(course_name)
print('Week,', week)
print('python foundation for AI/ML')
# Out:
# CAME
# Week, 1
# python foundation for AI/ML

# %%
#Weak names
x=0.91
data=[1, 0, 1, 1]

#Better names
validation_accuracy=0.91
target_labels=[1, 0, 1, 1]

print(validation_accuracy)
print(target_labels)
# Out:
# 0.91
# [1, 0, 1, 1]

# %%
sample_id='IMG_001'
label='cat'
width=224
confidence=0.9725
is_correct=True
notes=None

print(type(sample_id))
print(type(label))
print(type(width))
print(type(confidence))
print(type(is_correct))
print(type(notes))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
file_name='review_001.txt'
label='positive'

print(file_name.upper())
print(label=='positive')
# Out:
# REVIEW_001.TXT
# True

# %%
raw_label='    Positive       '
clean_label=raw_label.strip().lower()


print(clean_label)
print(clean_label=='positive')
# Out:
# positive
# True

# %%
print(len(raw_label))
# Out:
# 19

# %%
correct_prediction=87
total_predictions=100

accuracy=correct_prediction/total_predictions

print(accuracy)
print(accuracy*100)
# Out:
# 0.87
# 87.0

# %%
confidence=0.82
threshold=0.80

is_high_confidence=confidence>=threshold

print(is_high_confidence)
# Out:
# True

# %%
best_model_name=None

if best_model_name is None:
    print("No model selected yet")
# Out:
# No model selected yet

# %%
raw_age='35'
raw_score='0.91'

age=int(raw_age)
score=float(raw_score)

print(age+1)
print(score>0.8)
# Out:
# 36
# True

# %%
student_name:str="Nimal"
epoch_count:int=10
learning_rate:float=0.001
use_gpu:bool=False

score:list[float]=[0.82,0.87,0.91]
label_map:dict[str,int]={'cat':0,'dog':1}

# %%
model_name='baseline_logistic_regression'
accuracy=0.87345

print('Model:',model_name)
print("Accuracy:",accuracy)
# Out:
# Model: baseline_logistic_regression
# Accuracy: 0.87345

# %%
raw_threshold=input('Enter confidence threshold: ')
threshold=float(raw_threshold)

print(threshold)
print(threshold>=0.5)
# Out:
# 8.0
# True

# %%
model_name="Decision Tree"
accuracy=0.87345

print(f'Model: {model_name}')
print(f'Accuracy : {accuracy:.2%}')
print(f'Accuracy rounded: {accuracy:.3f}')
# Out:
# Model: Decision Tree
# Accuracy : 87.34%
# Accuracy rounded: 0.873

# %%
confidence=0.76
threshold=0.80

if confidence>=threshold:
    print("Accept prediction")
else:
    print("Send to human review")
# Out:
# Send to human review

# %%
score=0.68

if score>=0.85:
    label='strong'
elif score>=0.60:
    label='moderate'
else:
    label='weak'

print(label)
# Out:
# moderate

# %%
age=42
income=150000
has_missing_values=False
is_valid_customer=age>=18 and income>0 and not has_missing_values
print(is_valid_customer)
# Out:
# True

# %% [markdown]
# # Loops

# %%
predictions=['cat','dog','cat']

for prediction in predictions:
    print(f'Prediction class : {prediction}')
# Out:
# Prediction class : cat
# Prediction class : dog
# Prediction class : cat

# %%
epochs=5

for epoch in range(1,epochs+1):
    print(f'Epoch {epoch}/{epochs}')
# Out:
# Epoch 1/5
# Epoch 2/5
# Epoch 3/5
# Epoch 4/5
# Epoch 5/5

# %%
labels=['spam','not_spam','spam']

for index,label in enumerate(labels):
    print(f"Row {index}:{label}")
# Out:
# Row 0:spam
# Row 1:not_spam
# Row 2:spam
